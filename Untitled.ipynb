# %%
# %matplotlib inline
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact

x = np.linspace(-100, 100, 5000)
y = np.linspace(-100, 100, 5000)
x, y = np.meshgrid(x, y)
z = x**2+10*y**2

fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.contour3D(x, y, z, 50)
def f(a=30, b=35):
    ax.view_init(a, b)
    print (a, b)
interact (f, a = (-90, 90), b = (-90, 90))
# Out:
# interactive(children=(IntSlider(value=30, description='a', max=90, min=-90), IntSlider(value=35, description='…
# <function __main__.f(a=30, b=35)>
