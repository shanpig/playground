# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(-100, 100, 2000)
y=np.sqrt(x**2)
z=-np.sqrt(x**2)
plt.plot(x, y)
plt.plot(x, z )

# %%
ssh ycclab@140.112.55.136
# Out:
#   File "<ipython-input-4-04aae370b211>", line 1
#     ssh ycclab@140.112.55.136
#              ^
# SyntaxError: invalid syntax

# %%
a=1
for i in range(1, 10):
    a*=i
a
# Out:
# 362880
